# %% [markdown]
# <a href="https://colab.research.google.com/github/deniaulainfead23/bioinformatica/blob/main/aula04/PraticacomAlunas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Prática com alunas(os) de Biomedicina e Farmácia - 09 de setembro de 2026**::♥

# %%
nome = input('Seu nome: ')
sequencia = input('Sequência: ').upper()
tamanho = len(sequencia)
print('Tamanho:', tamanho)
# Out:
# Seu nome: Daiane
# Sequência: CTAFH
# Tamanho: 5

# %% [markdown]
# Daiane, Cleide, Lays, M. Vitória
#
# Responda no caderno:
# • Qual valor ficou em nome?
# • Qual valor ficou em tamanho?
# • O que .upper() fez?

# %%
sequencias = ['ATGC', 'GGCC', 'AATT']
print(sequencias[2])
amostra = {
  'id': 'A01',
  'grupo': 'Controle',
  'sequencia': 'ATGCGT'
}
print(amostra['id'],amostra['grupo'])

sequencias = ['ATGC', 'GGCC', 'AATT']
for sequencia in sequencias:
       print('Sequência:', sequencia)
       print('Tamanho:', len(sequencia))
# Out:
# AATT
# A01 Controle
# Sequência: ATGC
# Tamanho: 4
# Sequência: GGCC
# Tamanho: 4
# Sequência: AATT
# Tamanho: 4

# %% [markdown]
# SARA RANI, RAYSSA E CARLA

# %%
import pandas as pd
dados = pd.read_csv('base_python0_bioinformatica.csv')
print('Primeiras linhas:')
print(dados.head())
print('\nQuantidade de linhas:')
print(dados.shape[0])
print('\nColunas existentes:')
print(dados.columns.tolist())
print('\nValores ausentes por coluna:')
print(dados.isna().sum())
# Out:
# Primeiras linhas:
#   id_amostra     grupo  dia_coleta organismo_modelo           sequencia  \
# 0        A01  Controle           1         Modelo_A        ATGCGTACGTAA
# 1        A02  Controle           2         Modelo_A      ATATGCGTATGCGA
# 2        A03  Controle           3         Modelo_A    GCGTACGATCGTACGA
# 3        A04  Controle           4         Modelo_B    ATGCCGTTAACCGGTA
# 4        A05  Controle           5         Modelo_B  TTATTAACGATATTAACG
#
#    qualidade_media  temperatura_c  resposta_percentual laboratorio  \
# 0             36.0           36.5                  8.0       Lab_A
# 1             35.0           36.6                  9.0       Lab_A
# 2             37.0           36.4                  7.0       Lab_A
# 3             34.0           36.7                 10.0       Lab_B
# 4             33.0           36.5                 11.0       Lab_B
#
#                 observacao
# 0  Sem alteração observada
# 1  Sem alteração observada
# ...

# %% [markdown]
# andreza, bruna, ana caroline e thaina
